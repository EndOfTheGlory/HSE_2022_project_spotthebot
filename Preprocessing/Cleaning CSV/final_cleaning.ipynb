# %%
import pandas as pd
import numpy as np
import re
import nltk

# %%
# ! pip install nagisa
# Out:
# Collecting nagisa
#   Downloading nagisa-0.2.7-cp37-cp37m-win_amd64.whl (21.3 MB)
# Requirement already satisfied: six in c:\users\1\anaconda3\lib\site-packages (from nagisa) (1.14.0)
# Collecting DyNet
#   Downloading dyNET-2.1.2-cp37-cp37m-win_amd64.whl (5.1 MB)
# Requirement already satisfied: numpy in c:\users\1\anaconda3\lib\site-packages (from nagisa) (1.18.1)
# Requirement already satisfied: cython in c:\users\1\anaconda3\lib\site-packages (from DyNet->nagisa) (0.29.15)
# Installing collected packages: DyNet, nagisa
# Successfully installed DyNet-2.1.2 nagisa-0.2.7

# %%
import nagisa

# %%
whole_data = pd.read_csv("../Reading and bringing together wiki/GroupedArticles.csv")

# %%
whole_data
# Out:
#          pg_index                                            content
# 0               0  アンパサンドアンパサンド（&amp;, ）は、並立助詞「…と…」を意味する記号である。 ラテ...
# 1               1  言語言語（げんご）は、広辞苑や大辞泉には次のように解説されている。 『日本大百科事典』では、...
# 2               2  日本語 日本語（にほんご、にっぽんご、）は、日本国内や、かつての日本領だった国、そして日本人...
# 3               3  地理学地理学（ちりがく、、、伊：geografia、）は、。 地域や空間、場所、自然環境とい...
# 4               4  国の一覧国の一覧（くにのいちらん）は、世界の独立国の一覧。 対象.国際法上国家と言えるか否か...
# ...           ...                                                ...
# 1246611   1246611  藤白台藤白台（ふじしろだい）は大阪府吹田市にある地名。 千里ニュータウンにある住区である。 ...
# 1246612   1246612  林家たま平の青春スクラム『林家たま平の青春スクラム』（はやしやたまへいのせいしゅんすくらむ）...
# 1246613   1246613  いつかあの海で『いつかあの海で』（いつかあのうみで、英："Fleet Girls Colle...
# 1246614   1246614  ヴィクトル・ジュール・ルバスールヴィクトル・ジュール・ルバスール () はフランスの地理学者...
# 1246615   1246615  馬凡舒馬 凡舒（ば ぼんじょ、1993年11月6日 - ）は、中華人民共和国の司会者。 経歴...
#
# [1246616 rows x 2 columns]

# %%
full_text = pd.DataFrame()
for chunk in pd.read_csv("../Reading and bringing together wiki/GroupedArticles.csv", chunksize=100):
    full_text = pd.concat([full_text, chunk])
    break
full_text
# Out:
#     pg_index                                            content
# 0          0  アンパサンドアンパサンド（&amp;, ）は、並立助詞「…と…」を意味する記号である。 ラテ...
# 1          1  言語言語（げんご）は、広辞苑や大辞泉には次のように解説されている。 『日本大百科事典』では、...
# 2          2  日本語 日本語（にほんご、にっぽんご、）は、日本国内や、かつての日本領だった国、そして日本人...
# 3          3  地理学地理学（ちりがく、、、伊：geografia、）は、。 地域や空間、場所、自然環境とい...
# 4          4  国の一覧国の一覧（くにのいちらん）は、世界の独立国の一覧。 対象.国際法上国家と言えるか否か...
# ..       ...                                                ...
# 95        95  高橋しん高橋 しん（たかはし しん、本名：高橋 真（たかはし しん）、男性、1967年（昭和...
# 96        96  高屋奈月高屋 奈月（たかや なつき、1973年7月7日 - ）は、日本の漫画家。 東京都出身...
# 97        97  竹本泉竹本 泉（たけもと いずみ、本名・竹本 謙（たけもと けん）、1959年（昭和34年）...
# 98        98  寺沢武一寺沢 武一（てらさわ ぶいち、男性、1955年（昭和30年）3月30日 - ）は、日...
# 99        99  冨樫義博冨樫 義博（とがし よしひろ、本名同じ、1966年（昭和41年）4月27日 - ）は...
#
# [100 rows x 2 columns]

# %% [markdown]
# Used: https://kairozu.github.io/updates/cleaning-jp-text

# %%
def leave_only_japanese(text_to_fix: str):
    '''
    Function that leave only kanji, hiragana, katakana and period with comma.
    '''
    # we don't need ! or ? => don't use codes \uFF01\uFF1F
    where_is_japanese=r"[\u3040-\u309F \u30A0-\u30FF\u4E00-\u9FAF\u3400-\u4DB5\u4E00-\u9FCB\uF900-\uFA6A\u3002\uFF01\uFF1F]"
    please_work = ''.join(re.findall(where_is_japanese, text_to_fix))
    return please_work

    


def do_full_cleaning(our_text: str):
    final_text = leave_only_japanese(our_text)

        
    return final_text

# %%
checker = full_text['content'].apply(lambda text_one_by_one: do_full_cleaning(text_one_by_one))

# %%
one_article = checker[0]
one_article
# Out:
# 'アンパサンドアンパサンド は並立助詞とを意味する記号である。 ラテン語でとを表す接続詞  の合字を起源とする。 現代のフォントでも  など一部のフォントでは の合字であることが容易にわかる字形を使用している。 語源英語で教育を行う学校でアルファベットを復唱する場合その文字自体が単語となる文字  かつては  もについては伝統的にラテン語の それ自体を用いて     のように唱えられていた。 またアルファベットの最後に番目の文字のように  を加えることも広く行われていた。  はラテン語で  と読まれていたが後に英語で  と読まれるようになった。 結果としてアルファベットの復唱の最後は        という形になった。 この最後のフレーズが繰り返されるうちに  と訛っていきこの言葉は年までには英語の一般的な語法となった。 アンドレマリ・アンペールがこの記号を彼の著作で使いこれが広く読まれたためこの記号が   と呼ばれるようになったという誤った語源俗説がある。 歴史アンパサンドの起源は世紀の古ローマ筆記体にまで遡ることができる。 古ローマ筆記体では と  はしばしば合字として繋げて書かれていた左図アンパサンドの変遷の字形。 それに続く流麗さを増した新ローマ筆記体では様な合字が極めて頻繁に使われるようになった。 字形とは世紀中頃における  の合字の例である。 その後世紀のカロリング小文字体に至るラテン文字の変遷の過程で合字の使用は一般には廃れていった。 しかし の合字は使われ続け次第に元の文字がわかりにくい字形に変化していった字形から。 現代のイタリック体のアンパサンドはルネサンス期に発展した筆記体での  の合字に遡る。 年のヨーロッパにおける印刷技術の発明以降印刷業者はイタリック体とローマ筆記体のアンパサンドの両方を多用するようになった。 アンパサンドのルーツはローマ時代に遡るためラテンアルファベットを使用する多くの言語でアンパサンドが使用されるようになった。 アンパサンドはしばしばラテンアルファベットの最後の文字とされることがあった。 例えば年のの文字表がその例である。 同様に は英語アルファベットの番目の文字とされアメリカ合衆国やその他の地域でも子供達はアンパサンドはアルファベットの最後の文字だと教えられていた。 年の    の著書        にその一例を見ることができる。 ジョージ・エリオットは年に発表した小説の中で  に次のセリフを語らせている。                           よく知られた童謡の は             という歌詞で締めくくられる。 アンパサンドはティロ式記号の     とは別のものである。 ティロ式記号の  はアンパサンドと意味は同じだが数字のに似た形の記号である。 両者はともに古代から使用され中世を通してラテン語の  を表すために使用された。 しかしアンパサンドとティロ式記号の  はそれぞれ独立に発明されたものである。 ラテン文字から発展した古アイルランド語の文字ではアイルランド語の とを表すためにティロ式記号の  が使用されていた。 今日はゲール文字の一部として主に装飾的な目的で使用されている。 この文字はアイルランドにおけるキリスト教時代初期に修道院の影響によって書き文字に加わった可能性がある。 手書き日常的な手書きの場合欧米では小文字の エプシロンを大きくしたものあるいは数字の  の鏡文字に縦線を加えた形の単純化されたアンパサンドがしばしば使われる。 またエプシロンの上下に縦線または点を付けたものもしばしば使われる。 くだけた用法としてプラス記号 この記号もまた  の合字であるがアンパサンドの代わりに使われることもある。 またプラス記号に輪を重ねたような無声歯茎側面摩擦音を示す発音記号のようなものが使われることもある。 同様の記号ティロの速記にはを表すための   がある。 この文字はドイツのフラクトゥールで使われたほかゲール文字でも使用される。 ギリシア文字ではとを意味するを表すための合字として   が使われることがある。 プログラミング言語プログラミング言語では など多数の言語で  演算子として用いられる。 以下は  の例。 では変数宣言記号の直前に記述することで参照渡しを行うことができる。  系列の言語では文字列の連結演算子として使用される。  は  を返す。 また主にマイクロソフト系では整数の十六進表記に  を用い 十進でのように表現する。 ではアンパサンドを使って実体を参照する。'

# %% [markdown]
# How to separate japenese words: https://jprocessing.readthedocs.io/en/latest/, https://www.dampfkraft.com/nlp/how-to-tokenize-japanese.html,
#
# https://investigate.ai/text-analysis/splitting-words-in-east-asian-languages/

# %%
words_jap = nagisa.tagging(one_article)

# %%
stopping_words = pd.read_csv("stopwords-ja.txt", header=None)[0]
stopping_words
# Out:
# 0      あのかた
# 1      あります
# 2       あの人
# 3       あそこ
# 4        あっ
#        ...
# 130      私達
# 131       私
# 132     貴方方
# 133      貴方
# 134       る
# Name: 0, Length: 135, dtype: object

# %%
final_text = words_jap.words

# %%
final_text
# Out:
# ['アンパ',
#  'サンドアンパ',
#  'サンド',
#  '並立',
#  '助詞',
#  '意味',
#  '記号',
#  '。',
#  'ラテン',
#  '語',
#  '表す',
#  '接続',
#  '詞',
#  '合字',
#  '起源',
#  '。',
#  '現代',
#  'フォント',
#  '一部',
#  'フォント',
#  '合字',
#  '容易',
#  'わかる',
#  '字形',
#  '使用',
#  '。',
#  '語源',
#  '英語',
#  '教育',
#  '行う',
#  '学校',
#  'アルファベット',
#  '復唱',
#  '場合',
#  '文字',
#  '自体',
#  '単語',
#  '文字',
#  'つい',
#  '伝統',
#  '的',
#  'ラテン',
#  '語',
#  '自体',
#  '用い',
#  '唱え',
#  '。',
#  'アルファベット',
#  '最後',
#  '番目',
#  '文字',
#  '加える',
#  '広く',
#  '行わ',
#  '。',
#  'ラテン',
#  '語',
#  '読ま',
#  '後',
#  '英語',
#  '読ま',
#  '。',
#  '結果',
#  'アルファベット',
#  '復唱',
#  '最後',
#  '形',
#  '。',
#  '最後',
#  'フレーズ',
#  '繰り返さ',
#  '訛っ',
#  'いき',
#  '言葉',
#  '年',
#  '英語',
#  '一般',
#  '的',
#  '語法',
#  '。',
#  'アンドレマリ',
#  '・',
#  'アンペール',
#  '記号',
#  '著作',
#  '使い',
#  '広く',
#  '読ま',
#  '記号',
#  '呼ば',
#  '誤っ',
#  '語源',
#  '俗説',
#  '。',
#  '歴史',
#  'アンパサンド',
#  '起源',
#  '世紀',
#  '古',
#  'ローマ',
#  '筆記',
#  '体',
#  '遡る',
#  '。',
#  '古',
#  'ローマ',
#  '筆記',
#  '体',
#  'はしばしば',
#  '合字',
#  '繋げ',
#  '書か',
#  '左図',
#  'アンパサンド',
#  '変遷',
#  '字形',
#  '。',
#  '続く',
#  '流麗',
#  '増し',
#  '新',
#  'ローマ',
#  '筆記',
#  '体',
#  '様',
#  '合字',
#  '極めて',
#  '頻繁',
#  '使わ',
#  '。',
#  '字形',
#  '世紀',
#  '中頃',
#  'おけ',
#  '合字',
#  '例',
#  '。',
#  '後',
#  '世紀',
#  'カロリング',
#  '小',
#  '文字',
#  '体',
#  '至る',
#  'ラテン',
#  '文字',
#  '変遷',
#  '過程',
#  '合字',
#  '使用',
#  '一般',
#  '廃れ',
#  'いっ',
#  '。',
#  '合字',
#  '使わ',
#  '続け',
#  '次第',
#  '元',
#  '文字',
#  'わかり',
#  'にくい',
#  '字',
#  '形',
#  '変化',
#  'いっ',
#  '字形',
#  '。',
#  '現代',
#  'イタリック',
#  '体',
#  'アンパサンド',
#  'ルネサンス',
#  '期',
#  '発展',
#  '筆記',
#  '体',
#  '合字',
#  '遡る',
#  '。',
#  '年',
#  'ヨーロッパ',
#  'おけ',
#  '印刷',
#  '技術',
#  '発明',
#  '以降',
#  '印刷',
#  '業',
#  '者',
#  'イタリック',
#  '体',
#  'ローマ',
#  '筆記',
#  '体',
#  'アンパサンド',
#  '両方',
#  '多用',
#  '。',
#  'アンパサンド',
#  'ルーツ',
#  'ローマ',
#  '時代',
#  '遡る',
#  'ラテン',
#  'アルファベット',
#  '使用',
#  '多く',
#  '言語',
#  'アンパ',
#  'サンド',
#  '使用',
#  '。',
#  'アンパサンド',
#  'しばしば',
#  'ラテン',
#  'アルファベット',
#  '最後',
#  '文字',
#  '。',
#  '例えば',
#  '年',
#  '文字',
#  '表',
#  '例',
#  '。',
#  '同様',
#  '英語',
#  'アルファベット',
#  '番目',
#  '文字',
#  'アメリカ',
#  '合衆',
#  '国',
#  '他',
#  '地域',
#  '子供',
#  '達',
#  'アンパサンド',
#  'アルファベット',
#  '最後',
#  '文字',
#  '教え',
#  '。',
#  '年',
#  '著書',
#  '一',
#  '例',
#  '見る',
#  '。',
#  'ジョージ',
#  '・',
#  'エリオット',
#  '年',
#  '発表',
#  '小説',
#  '中',
#  '次',
#  'セリフ',
#  '語ら',
#  '。',
#  'よく',
#  '知ら',
#  '童謡',
#  '歌詞',
#  '締めくくら',
#  '。',
#  'アンパサンド',
#  'ティロ',
#  '式',
#  '記号',
#  '別',
#  '。',
#  'ティロ',
#  '式',
#  '記号',
#  'アンパ',
#  'サンド',
#  '意味',
#  '同じ',
#  '数字',
#  '似',
#  '形',
#  '記号',
#  '。',
#  '両者',
#  '古代',
#  '使用',
#  '中世',
#  '通し',
#  'ラテン',
#  '語',
#  '表す',
#  '使用',
#  '。',
#  'アンパサンド',
#  'ティロ',
#  '式',
#  '記号',
#  '独立',
#  '発明',
#  '。',
#  'ラテン',
#  '文字',
#  '発展',
#  '古',
#  'アイルランド',
#  '語',
#  '文字',
#  'アイルランド',
#  '語',
#  '表す',
#  'ティロ',
#  '式',
#  '記号',
#  '使用',
#  '。',
#  '今日',
#  'ゲール',
#  '文字',
#  '一部',
#  '主に',
#  '装飾',
#  '的',
#  '目的',
#  '使用',
#  '。',
#  '文字',
#  'アイルランド',
#  'おけ',
#  'キリスト',
#  '教',
#  '時代',
#  '初期',
#  '修道',
#  '院',
#  '影響',
#  'よっ',
#  '書き',
#  '文字',
#  '加わっ',
#  '可能',
#  '性',
#  '。',
#  '手書き',
#  '日常',
#  '的',
#  '手書き',
#  '場合',
#  '欧米',
#  '小',
#  '文字',
#  'エプシロン',
#  '大きく',
#  'あるいは',
#  '数字',
#  '鏡',
#  '文字',
#  '縦線',
#  '加え',
#  '形',
#  '単純',
#  '化',
#  'アンパサンド',
#  'しばしば',
#  '使わ',
#  '。',
#  'エプシロン',
#  '上下',
#  '縦線',
#  '点',
#  '付け',
#  'しばしば',
#  '使わ',
#  '。',
#  'くだけ',
#  '用法',
#  'プラス',
#  '記号',
#  '記号',
#  '合字',
#  'アンパ',
#  'サンド',
#  '代わり',
#  '使わ',
#  '。',
#  'プラス',
#  '記号',
#  '輪',
#  '重ね',
#  '無声',
#  '歯茎',
#  '側面',
#  '摩擦',
#  '音',
#  '示す',
#  '発音',
#  '記号',
#  '使わ',
#  '。',
#  '同様',
#  '記号',
#  'ティロ',
#  '速記',
#  '表す',
#  '。',
#  '文字',
#  'ドイツ',
#  'フラクトゥール',
#  '使わ',
#  'ゲール',
#  '文字',
#  '使用',
#  '。',
#  'ギリシア',
#  '文字',
#  '意味',
#  '表す',
#  '合字',
#  '使わ',
#  '。',
#  'プログラミング',
#  '言語',
#  'プログラミング',
#  '言語',
#  '多数',
#  '言語',
#  '演算',
#  '子',
#  '用い',
#  '。',
#  '以下',
#  '例',
#  '。',
#  '変数',
#  '宣言',
#  '記号',
#  '直前',
#  '記述',
#  '参照',
#  '渡し',
#  '行う',
#  '。',
#  '系列',
#  '言語',
#  '文字',
#  '列',
#  '連結',
#  '演算',
#  '子',
#  '使用',
#  '。',
#  '返す',
#  '。',
#  '主に',
#  'マイクロ',
#  'ソフト',
#  '系',
#  '整数',
#  '十',
#  '六',
#  '進',
#  '表記',
#  '用い',
#  '十',
#  '進',
#  '表現',
#  '。',
#  'アンパ',
#  'サンド',
#  '使っ',
#  '実体',
#  '参照',
#  '。']

# %%
def remove_values_from_list(the_list, val):
   return [value for value in the_list if value != val]

for one_stop in stopping_words:
    if one_stop in final_text:
#         final_text.remove(one_stop)
        final_text = remove_values_from_list(final_text, one_stop)
final_text = remove_values_from_list(final_text, "\u3000")

# %%
new_article_pure = ""
for one_word in final_text:
    new_article_pure += one_word + " "
new_article_pure
# Out:
# 'アンパ サンドアンパ サンド 並立 助詞 意味 記号 。 ラテン 語 表す 接続 詞 合字 起源 。 現代 フォント 一部 フォント 合字 容易 わかる 字形 使用 。 語源 英語 教育 行う 学校 アルファベット 復唱 場合 文字 自体 単語 文字 つい 伝統 的 ラテン 語 自体 用い 唱え 。 アルファベット 最後 番目 文字 加える 広く 行わ 。 ラテン 語 読ま 後 英語 読ま 。 結果 アルファベット 復唱 最後 形 。 最後 フレーズ 繰り返さ 訛っ いき 言葉 年 英語 一般 的 語法 。 アンドレマリ ・ アンペール 記号 著作 使い 広く 読ま 記号 呼ば 誤っ 語源 俗説 。 歴史 アンパサンド 起源 世紀 古 ローマ 筆記 体 遡る 。 古 ローマ 筆記 体 はしばしば 合字 繋げ 書か 左図 アンパサンド 変遷 字形 。 続く 流麗 増し 新 ローマ 筆記 体 様 合字 極めて 頻繁 使わ 。 字形 世紀 中頃 おけ 合字 例 。 後 世紀 カロリング 小 文字 体 至る ラテン 文字 変遷 過程 合字 使用 一般 廃れ いっ 。 合字 使わ 続け 次第 元 文字 わかり にくい 字 形 変化 いっ 字形 。 現代 イタリック 体 アンパサンド ルネサンス 期 発展 筆記 体 合字 遡る 。 年 ヨーロッパ おけ 印刷 技術 発明 以降 印刷 業 者 イタリック 体 ローマ 筆記 体 アンパサンド 両方 多用 。 アンパサンド ルーツ ローマ 時代 遡る ラテン アルファベット 使用 多く 言語 アンパ サンド 使用 。 アンパサンド しばしば ラテン アルファベット 最後 文字 。 例えば 年 文字 表 例 。 同様 英語 アルファベット 番目 文字 アメリカ 合衆 国 他 地域 子供 達 アンパサンド アルファベット 最後 文字 教え 。 年 著書 一 例 見る 。 ジョージ ・ エリオット 年 発表 小説 中 次 セリフ 語ら 。 よく 知ら 童謡 歌詞 締めくくら 。 アンパサンド ティロ 式 記号 別 。 ティロ 式 記号 アンパ サンド 意味 同じ 数字 似 形 記号 。 両者 古代 使用 中世 通し ラテン 語 表す 使用 。 アンパサンド ティロ 式 記号 独立 発明 。 ラテン 文字 発展 古 アイルランド 語 文字 アイルランド 語 表す ティロ 式 記号 使用 。 今日 ゲール 文字 一部 主に 装飾 的 目的 使用 。 文字 アイルランド おけ キリスト 教 時代 初期 修道 院 影響 よっ 書き 文字 加わっ 可能 性 。 手書き 日常 的 手書き 場合 欧米 小 文字 エプシロン 大きく あるいは 数字 鏡 文字 縦線 加え 形 単純 化 アンパサンド しばしば 使わ 。 エプシロン 上下 縦線 点 付け しばしば 使わ 。 くだけ 用法 プラス 記号 記号 合字 アンパ サンド 代わり 使わ 。 プラス 記号 輪 重ね 無声 歯茎 側面 摩擦 音 示す 発音 記号 使わ 。 同様 記号 ティロ 速記 表す 。 文字 ドイツ フラクトゥール 使わ ゲール 文字 使用 。 ギリシア 文字 意味 表す 合字 使わ 。 プログラミング 言語 プログラミング 言語 多数 言語 演算 子 用い 。 以下 例 。 変数 宣言 記号 直前 記述 参照 渡し 行う 。 系列 言語 文字 列 連結 演算 子 使用 。 返す 。 主に マイクロ ソフト 系 整数 十 六 進 表記 用い 十 進 表現 。 アンパ サンド 使っ 実体 参照 。 '

# %%
def remove_values_from_list(the_list, val):
   return [value for value in the_list if value != val]

def spearating_deleting_stopwords(data, stopwords):
    i = 0
    for one_art in data:
        words_in_art = nagisa.tagging(one_art).words
        for one_stop in stopwords:
            if one_stop in words_in_art:
                words_in_art = remove_values_from_list(words_in_art, one_stop)
        words_in_art = remove_values_from_list(words_in_art, "\u3000")
        new_article_cleaned = ""
        for one_word in words_in_art:
            new_article_cleaned += one_word + " "
        # we don't need ! or ? => we change \uFF01\uFF1F to \u3002
        new_article_cleaned = new_article_cleaned.replace("\uFF01", "\u3002")
        new_article_cleaned = new_article_cleaned.replace("\uFF1F", "\u3002")
        new_article_cleaned = new_article_cleaned.replace("!", "\u3002")
        new_article_cleaned = new_article_cleaned.replace("?", "\u3002")
        data[i] = new_article_cleaned
        i += 1

# %%
pure_text = checker.copy()[:3]

# %%
pure_text
# Out:
# 0    アンパサンドアンパサンド は並立助詞とを意味する記号である。 ラテン語でとを表す接続詞  の...
# 1    言語言語げんごは広辞苑や大辞泉には次のように解説されている。 日本大百科事典では言語という語...
# 2    日本語 日本語にほんごにっぽんごは日本国内やかつての日本領だった国そして日本人同士の間で使用...
# Name: content, dtype: object

# %%
spearating_deleting_stopwords(pure_text, stopping_words)

# %%
pure_text
# Out:
# 0    アンパ サンドアンパ サンド 並立 助詞 意味 記号 。 ラテン 語 表す 接続 詞 合字 ...
# 1    言語 言語 げんご 広 辞苑 大 辞泉 次 解説 。 日本 大 百 科 事典 言語 語 多義...
# 2    日本 語 日本 語 ほんご っぽんご 日本 国 内 日本 領 国 日本 人 同士 間 使用 ...
# Name: content, dtype: object

# %%
whole_pure_text = checker.copy()
spearating_deleting_stopwords(whole_pure_text, stopping_words)

# %%
whole_pure_text
# Out:
# 0     アンパ サンドアンパ サンド 並立 助詞 意味 記号 。 ラテン 語 表す 接続 詞 合字 ...
# 1     言語 言語 げんご 広 辞苑 大 辞泉 次 解説 。 日本 大 百 科 事典 言語 語 多義...
# 2     日本 語 日本 語 ほんご っぽんご 日本 国 内 日本 領 国 日本 人 同士 間 使用 ...
# 3     地理 学 地理 学 ちりがく 伊 。 地域 空間 場所 自然 環境 物理 的 存在 対象 中...
# 4     国 一覧 国 一覧 くにのいちらん 世界 独立 国 一覧 。 対象 国際 法 上 国家 言え...
#                             ...
# 95    高橋 しん 高橋 しんた しん本 名 高橋 真 たか しん 男性 年 昭和 年 月 日 日本...
# 96    高屋奈月 高屋 奈月 なつき 年 月 日 日本 漫画 家 。 東京 都 出身 。 血液 型 ...
# 97    竹本 泉 竹本 泉 たけもと いずみ 本名 ・ 竹本 謙 たけもと けん 年 昭和 年 月 ...
# 98    寺沢 武一寺沢 武 一 てらさわ ぶいち 男性 年 昭和 年 月 日 日本 漫画 家 。 北...
# 99    冨樫 義博 冨樫 義博 とがし よしひろ 本名 同じ 年 昭和 年 月 日 日本 漫画 家 ...
# Name: content, Length: 100, dtype: object

# %% [markdown]
# let's work with lemmatization

# %%
result = pure_text.copy()

# %%
import stanza

nlp = stanza.Pipeline(lang='ja', processors='tokenize, lemma')
# doc = nlp(without_stopwords[0])
doc = nlp(pure_text[0])
# Out:
# Loading these models for language: ja (Japanese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | lemma     | gsd     |
# =======================
#
# Use device: cpu
# Loading: tokenize
# Loading: lemma
# Done loading processors!

# %%
to_check_res = ' '.join([word.lemma for sent in doc.sentences for word in sent.words])
to_check_res
# Out:
# 'アンパ サンド アンパ サンド 並立 助詞 意味 記号 。 ラテン 語 表す 接続 詞 合字 起源 。 現代 フォント 一部 フォント 合字 容易 わかる 字 形 使用 。 語源 英 語 教育 行う 学校 アルファベット 復唱 場合 文字 自体 単語 文字 つく 伝統 的 ラテン 語 自体 用いる 唱える 。 アルファベット 最 後 番 目 文字 加える 広い 行う 。 ラテン 語 読ま 後 英語 読ま 。 結果 アルファベット 復唱 最後 形 。 最後 フレーズ 繰り返さ 訛っ いく 言葉 年 英語 一般 的 語法 。 アンドレマリ ・ アンペール 記号 著作 使う 広い 読ま 記号 呼ぶ 誤る 語 源 俗説 。 歴史 アンパサンド 起源 世紀 古 ローマ 筆記 体 遡る 。 古 ローマ 筆記 体 は しばしば 合字 繋げ 書く 左図 アンパサンド 変遷 字 形 。 続く 流麗 増す 新 ローマ 筆記 体 よう 合字 極めて 頻繁 使う 。 字 形 世紀 中頃 おく 合字 例 。 後 世紀 カロリング 小 文字 体 至る ラテン 文字 変遷 過程 合字 使用 一般 廃れる いう 。 合字 使う 続ける 次 第 元 文字 わかる にくい 字 形 変化 いう 字 形 。 現代 イタリック 体 アンパサンド ルネサンス 期 発展 筆記 体 合字 遡る 。 年 ヨーロッパ おく 印刷 技術 発明 以降 印刷 業 者 イタリック 体 ローマ 筆記 体 アンパサンド 両 方 多用 。 アンパサンド ルーツ ローマ 時代 遡る ラテン アル ファベット 使 用 多い 言語 アンパ サンド 使用 。 アンパサンド しばしば ラテン アルファベット 最後 文字 。 例えば 年 文字 表 例 。 同様 英語 アルファベット 番 目 文字 アメリカ 合衆 国 他 地域 子供 達 アンパサンド アルファベット 最後 文字 教える 。 年 著書 一 例 みる 。 ジョージ ・ エリオット 年 発表 小説 中 次 セリフ 語る 。 よく 知る 童謡 歌詞 締める くい 。 アンパサンド ティロ 式 記号 別 。 ティロ 式 記号 アンパ サンド 意味 同じ 数字 似る 形 記号 。 両者 古代 使用 中世 通す ラテン 語 表す 使用 。 アンパサンド ティロ 式 記号 独立 発明 。 ラテン 文字 発展 古 アイルランド 語 文字 アイルランド 語 表す ティロ 式 記号 使用 。 今日 ゲール 文字 一 部 主 に 装飾 的 目 的 使用 。 文字 アイルランド おく キリスト 教 時代 初 期 修道 院 影響 よる 書し 文字 加わる 可能 性 。 手書き 日常 的 手書き 場合 欧米 小 文字 エプシロン 大きい あるいは 数字 鏡 文字 縦 線 加える 形 単純 化 アンパサンド しばしば 使う 。 エプシロン 上下 縦線 点 付ける しばしば 使う 。 くだけ 用法 プラス 記号 記号 合字 アンパ サンド 代わり 使う 。 プラス 記号 輪 重ねる 無声 歯茎 側面 摩擦 音 示す 発音 記号 使う 。 同様 記号 ティロ 速 記 表す 。 文字 ドイツ フラクトゥール 使う ゲール 文字 使用 。 ギリシア 文字 意味 表す 合字 使う 。 プログラミング 言 語 プログラミング 言語 多数 言語 演算 子 用いる 。 以下 例 。 変数 宣言 記号 直 前 記述 参照 渡す 行う 。 系列 言語 文字 列 連結 演算 子 使用 。 返す 。 主に マイクロ ソフト 系 整数 十 六 進 表記 用いる 十 進 表現 。 アンパ サンド 使う 実体 参照 。'

# %%
for i in range(len(result)):
    doc = nlp(result[i])
    words_array = [word.lemma for sent in doc.sentences for word in sent.words]
    whole_article_again = ""
    for word_or_comma in words_array:
        if word_or_comma != None:
            whole_article_again += word_or_comma + " "
#     final = ' '.join([word.lemma for sent in doc.sentences for word in sent.words if word != None])
    result[i] = whole_article_again

# %%
result[2]
# Out:
# '日本 語 日本 語 ほんご いたす ご 日本 国 内 日本 領 国 日本 人 同士 間 使用 言語 。 日本 法 令 よる 公 用 語 規定 法 令 他 公 用 文 全て 日本 語 記述 各種 法 令 おく 日本 語 用いる 規定 学校 教育 おく 国 語 教 科 学習 行う 等 事実 上 日本 国 内 おく 唯一 公用 語 。 使用 人口 つく 正確 統計 日本 国 内 人口 日本 国 外 住む 日本 人 日系 人 日本 統治 地域 一 部 住民 約 億 千 万 人 以上 考える 。 統計 よる 前 後 場合 数 世界 母 語 話 者 数 上位 位 以内 入る 人数 。 日本 生まれ育い 人 日本 語 母語 。 日本 語 文法 体 系 音韻 体 系 反映 手 話 日本 語 対応 手話 。 年 月 現在 インターネット 上 言語 使用 者 数 英語 中国 語 スペイン 語 アラビア 語 ポルトガル 語 マレー 語 インドネシア 語 フランス 語 次ぐ 番 目 多い 。 特徴 日本 語 音韻 はっん 除い 母音 終わる 開音 節言 語 性格 強い 標準 語 共通 語 含める 多い 方言 モーラ 持つ 。 アクセント 高 低 アクセント 。 元来 古い 大和 言葉 原則 特徴 系統 音韻 節 参照 。 文 主語 ・ 修飾 語 ・ 述語 語 順 構成 。 修飾 語 被修 飾 語 前 位置 。 名詞 格 示す 語 順 語尾 変 化 文 法 的 機能 示す 機能 語 助詞 後ろ 付け加える 膠着 。 言語 類 型 論 上 語 順 点 型 言語 形態 点 膠着 語 分類 文法 節 参照 。 語彙 古来 大和 言葉 和 語 漢 語 字 音語 外来 語 混ざい 混種 語 分ける 。 字 音語 漢字 音読み 由来 語 意 一般 漢 語 称する 漢 文 通す 古代 ・ 中世 中国 渡来 語 派生 語彙 現代 語彙 過 半数 占める 。 紙かみ 絵画 ゑ もともと 音 和 語 認識 。 近代 以降 西 洋 由来 語 中心 外来 語 増大 語 種 節 参照 。 待遇 表現 面 文法 的 ・ 語彙 的 発達 敬 語 体 系 叙述 人物 どうし 微妙 関係 表現 待遇 表現 節 参照 。 日本 語 地 方 ごと 多様 方言 ありとり わけ 琉球 諸島 方言 差 著しい 方言 節 参照 。 近世 中期 京 都 方言 中央 語 地位 近世 後 期 江戸 方言 地位 高める 明治 以降 現代 日本 語 東京 山 手 中流 階 級 以上 方言 山 手言葉 基盤 標準 語 共通 語 形成 標準 語 参照 。 表記 体 系 諸 言語 比べる 極めて 複雑 かつ 柔軟 性 高 特徴 。 漢字 国 字 含む 。 音読み 訓 読む 用いる 平 仮名 片 仮名 日本 語 主要 文字 常 種 類 文字 組み合わせる 表記 字 種 節 参照 。 表音 文字 表 記 体 系 複数 持つ 当 て 字 外来 語 表記 可能 ラテン 文字 ローマ 字 ギリシャ 文字 医 学 ・ 科学 用 語 多用 しばしば 用いる 。 縦書き 横書き どちら 表記 可能 表 記 体 系 詳細 つく 日本 語 表記 体 系 参照 。 音韻 子 音 母 音 音節 基本 母音 種 類 しか 分かる やすい 構造 持つ 一方 直音 拗 音 対立 音節 モーラ 存在 無 声 化 母音 語 組み立てる 伴う 移動 高 アクセント 特徴 音韻 節 参照 。 分布 日本 語 主 に 日本 国 内 使用 。 話者 人口 つく 調査 国 内 ・ 国外 問う いま 日本 人口 基づく 考える 一般 的 。 日本 国 内 法 令 上 日本 語 公用 語 国 語 定める 直接 規定 。 法令 日本 語 記す 裁判 所 法 おく 裁判 所 日本 語 用いる 同法 条 文字 ・ 活字 文 化 振興 法 おく 国 語 日本 語 同一 視 同法 条 条 他 多い 法 令 おく 日本 語 唯一 公用 語 国 語 前提 。 法 文 だけ 公用 文 すべて 日本 語 用いる 学校 教育 日本 語 国 語 教える 。 日本 テレビ ラジオ 映画 放送 小説 漫画 新聞 出版 分野 日本 語 使う 。 国外 ドラマ 映画 放送 場合 基本 的 日本 語 訳す 字幕 付ける 声 当てる 放送 受ける 手 日本 語 理解 前提 作成 。 原語 まま 放送 ・ 出版 存在 外国 向ける 発表 前 提 論 文 もしい は 日本 在住 外 国 人 あるいは 原語 学習 者 限る 人 対象 大 多数 日本 人 向ける 。 日本 国 外 主 中 南米 ペルー ・ ブラジル ・ ボリビア ・ ドミニカ 共和 国 ・ パラグアイ ハワイ 日本 人 移民 間 日本 語 使用 みる 世 ・ 世 世代 下るい した がう 非 日本 語 話 者 多い 。 太平 洋 戦争 終結 以前 日本 領 日本 勢力 下 朝鮮 総督 府 朝鮮 半島 ・ 台湾 総督 府 台 湾 ・ 旧 満州 国 現在 中華 人民 共和 国 一部 ・ 樺太 庁 樺太 サハリン ・ 旧 南洋 庁 南洋 諸島 現在 北マリアナ 諸島 ・ パラオ ・ マーシャル 諸島 ・ ミクロネシア 連邦 地域 日本 語 教育 受ける 人 中 現在 日本 語 記憶 話す 人 。 台湾 先住 民 異なる 部族 同士 会 話 日本 語 用いる だけ 宜蘭 クレオール 日本 語 タイヤル 語 クレオール 言 語 存在 。 パラオ アンガウル 州 歴史 的 経緯 日本 語 公用 語 一 採用 現在 州 内 日本 語 日常 会 話 用いる 住民 存在 象徴 的 留まる 。 日本 国 外 日本 語 学習 者 年 調査 万 人 のぼり 中華 人民 共和 国 約 万 人 インドネシア 約 万 人 大 韓 民 国 約 万 人 オーストラリア 約 万 人 台湾 約 万 人 上位 。 地域 別 東 アジア ・ 東南 アジア 全体 学習 者 約 割 占める 。 日本 語 教育 行う 地域 か国 ・ 地域 及ぶ 。 日本 国 内 日本 語 学習 者 アジア 地域 約 万 人 中心 約 万 人 上る 。 系統 日本 語 範囲 本土 方言 場合 琉球 語 日本 語 同 系統 言 語 両 者 日 琉 語 族 形成 。 琉球 列 島 旧 琉球 王国 領域 言葉 日本 語 系統 同じく 別 言語 琉球 語 琉球 諸 語 日本 語 まとめる 日 琉 語 族 。 共通 点 多い 日本 語 一 方言 琉球 方言 場合 場合 日本 語 孤立 言語 位置 づけ 。 日本 語 族 系統 明らか 年 年 書物 いく 理論 仮 説 いまだ 総意 える 至る 記述 。 学問 的 系統 断言 言語 学 的 しばしば 孤立 言語 分類 多い 。 アルタイ 諸語 属 する 説 明治 時代 末 注目 。 根拠 古代 日本 語 大和 言葉 おく 語頭 音流 音 立つ 一種 母音 調和 みる 挙げる 。 古代 日本 語 上記 特徴 みる 日本 語 類 型 アルタイ 型 言語 根拠 。 日本 語 トルコ 系 言語 基礎 語彙 似る 部分 意味 日本 語 はい ウズベク 語 ハ 。 アルタイ 諸語 属 する 言 語 親族 関係 支持 学 者 ほう まだ 多い 最近 イギリス アルタイ 諸語 親族 関係 否定 学 者 現れる 。 アイヌ 語 語 順 語 順 おく 日本 語 似る 。 文法 ・ 形態 類 型 論 的 異なる 抱合 語 属する 音韻 構造 有声 ・ 無声 区 別 ない 閉 音節 多い 相違 。 基礎 語 彙 類似 関する 指摘 例 不 充分 。 一般 似る 語 中 日本 語 アイヌ 語 借 用 語 多い 含む みる 。 朝鮮 語 語 順 文法 構造 類似 点 非常 多い 。 音韻 面 固有 語 おく 語頭 流音 立 た 一種 母音 調和 みる 共通 類似 点 結果 日本 語 朝鮮 語 アルタイ 諸語 分類 場合 。 世界 諸 言語 広い 比較 場合 広い 朝鮮 語 日本 語 最も 近い 言語 。 閉音 節 子音 連結 存在 有声 ・ 無声 区 別 ない いう 相違 。 基礎 語彙 共通 点 かなり 相違 面 。 基礎 語 彙 関連 朝鮮 半島 死語 高句 麗 語 数詞 重要 基礎 語彙 似る 新村 出る 指摘 。 高句 麗 語 記録 非常 少 ない 合わせる 約 単語 記録 保存 。 高句 麗 語 鉛 なまり 那勿 ナムル 泉 いずみ 於乙 呼ぶ 記録 高句 麗 武将 泉 蓋 蘇 文 日本 書紀 伊梨 柯須 彌 イリカスミ 記録 泉 いずみ 高句 麗 語 於乙 イリ 呼ぶ 分かる 。 高句 麗 語 水 買 マイ 土 つしい 内谷 旦 口くち 口 次 三 密 五 于 次七 難隱 十 德 高句 麗語 訓読み 現代 朝鮮 語 訓読み 日本 語 訓読み 非常 似る 分かる 。 中国 語 関係 関する 日本 語 中国 漢字 借用 語 広 範囲 取り入れる 語彙 漢字 用いる 関する 大きい だ 影響 受ける 。 語 順 文法 音韻 大きい 異なる 系統 論 的 別 系統 言語 。 南方 系 オーストロネシア 語 族 音韻 体 系 語彙 関する 類似 指摘 。 ドラヴィダ 語 族 関係 主張 説 認める 研究 者 少 ない 。 大野 晋 日本 語 語彙 ・ 文法 点 タミル 語 共通 点 持つ 説 唱える 比較 言語 学 方法 上 問題 批判 多い レプチャ 語 ・ ヘブライ 語 同系 論 過去 存在 関する 疑 ...

# %%
len(result)

# %%
result_whole = whole_pure_text.copy()
for i in range(len(result_whole)):
    doc = nlp(result_whole[i])
    words_array = [word.lemma for sent in doc.sentences for word in sent.words]
    whole_article_again = ""
    for word_or_comma in words_array:
        if word_or_comma != None:
            whole_article_again += word_or_comma + " "
    result_whole[i] = whole_article_again

# %%
result_whole
# Out:
# 0     アンパ サンド アンパ サンド 並立 助詞 意味 記号 。 ラテン 語 表す 接続 詞 合字...
# 1     言語 言語 げんご 広 辞苑 大 辞泉 次 解説 。 日本 大 百 科 事典 言語 語 多義...
# 2     日本 語 日本 語 ほんご ぽし ご 日本 国 内 日本 領 国 日本 人 同士 間 使用 ...
# 3     地理 学 地理 学 ちりがい 伊 。 地域 空間 場所 自然 環境 物理 的 存在 対象 中...
# 4     国 一覧 国 一覧 い に の いちらん 世界 独立 国 一覧 。 対象 国 際 法 上 国...
#                             ...
# 95    高橋 しん 高橋 しん た しん 本 名 高橋 真 たく しん 男 性 年 昭和 年 月 日...
# 96    高屋 奈月 高屋 奈月 なつき 年 月 日 日本 漫画 家 。 東京 都 出身 。 血液 型...
# 97    竹本 泉 竹本 泉 たけ もと いずみ 本名 ・ 竹本 謙 たけ もと けん 年 昭和 年 ...
# 98    寺沢 武 一 寺沢 武 一 てらさわ ぶいち 男性 年 昭和 年 月 日 日本 漫画 家 。...
# 99    冨樫 義博 冨樫 義博 とがし よしひろ 本名 同じ 年 昭和 年 月 日 日本 漫画 家 ...
# Name: content, Length: 100, dtype: object

# %%
result_whole.to_csv("fully_cleaned_trial_100_with_sep.csv", index=False)

# %% [markdown]
# Now transfrom all hiragana we can to kanji

# %%
words_array = [word.lemma for sent in doc.sentences for word in sent.words]

# %%
whole_article_again = ""
for word_or_comma in words_array:
    if word_or_comma != None:
        whole_article_again += word_or_comma + " "
whole_article_again
# Out:
# '日本 語 日本 語 ほんご ぽし ご 日本 国 内 日本 領 国 日本 人 同士 間 使用 言語 。 日本 法令 よる 公用 語 規定 法 令 他 公 用 文 全て 日本 語 記述 各種 法 令 おく 日本 語 用いる 規定 学校 教育 おく 国 語 教 科 学習 行う 等 事実 上 日本 国 内 おく 唯一 公用 語 。 使用 人口 つく 正確 統計 日本 国 内 人口 日本 国 外 住む 日本 人 日系 人 日本 統治 地域 一 部 住民 約 億 千 万 人 以上 考える 。 統計 よる 前 後 場合 数 世界 母 語 話 者 数 上位 位 以内 入る 人数 。 日本 生まれ育い 人 日本 語 母語 。 日本 語 文法 体 系 音韻 体 系 反映 手 話 日本 語 対応 手話 。 年 月 現在 インターネット 上 言語 使用 者 数 英語 中国 語 スペイン 語 アラビア 語 ポルトガル 語 マレー 語 インドネシア 語 フランス 語 次ぐ 番 目 多い 。 特徴 日本 語 音韻 はっん 除く 母音 終わる 開音 節言 語 性格 強い 標準 語 共通 語 含める 多い 方言 モーラ 持つ 。 アクセント 高 低 アクセント 。 元来 古い 大和 言葉 原則 特徴 系統 音韻 節 参照 。 文 主語 ・ 修飾 語 ・ 述語 語 順 構成 。 修飾 語 被修 飾 語 前 位置 。 名詞 格 示す 語 順 語尾 変 化 文 法 的 機能 示す 機能 語 助詞 後ろ 付け加える 膠着 。 言語 類 型 論 上 語 順 点 型 言語 形態 点 膠着 語 分類 文法 節 参照 。 語彙 古来 大和 言葉 和 語 漢 語 字 音語 外来 語 混ざい 混種 語 分ける 。 字 音語 漢字 音読み 由来 語 意 一般 漢 語 称する 漢 文 通す 古代 ・ 中世 中国 渡来 語 派生 語彙 現代 語彙 過 半数 占める 。 紙かみ 絵画 ゑ もともと 音 和 語 認識 。 近代 以降 西 洋 由来 語 中心 外来 語 増大 語 種 節 参照 。 待遇 表現 面 文法 的 ・ 語彙 的 発達 敬 語 体 系 叙述 人物 どうし 微妙 関係 表現 待遇 表現 節 参照 。 日本 語 地 方 ごと 多様 方言 ありとり わけ 琉球 諸島 方言 差 著しい 方言 節 参照 。 近世 中期 京 都 方言 中央 語 地位 近世 後 期 江戸 方言 地位 高める 明治 以降 現代 日本 語 東京 山 手 中流 階 級 以上 方言 山 手言葉 基盤 標準 語 共通 語 形成 標準 語 参照 。 表記 体 系 諸 言語 比べる 極めて 複雑 かつ 柔軟 性 高 特徴 。 漢字 国 字 含む 。 音読み 訓 読む 用いる 平 仮名 片 仮名 日本 語 主要 文字 常 種 類 文字 組み合わせる 表記 字 種 節 参照 。 表音 文字 表 記 体 系 複数 持つ 当 て 字 外来 語 表記 可能 ラテン 文字 ローマ 字 ギリシャ 文字 医 学 ・ 科学 用 語 多用 しばしば 用いる 。 縦書き 横書き どちら 表記 可能 表 記 体 系 詳細 つく 日本 語 表記 体 系 参照 。 音韻 子 音 母 音 音節 基本 母音 種 類 しか 分かる やすい 構造 持つ 一方 直音 拗 音 対立 音節 モーラ 存在 無 声 化 母音 語 組み立てる 伴う 移動 高 アクセント 特徴 音韻 節 参照 。 分布 日本 語 主 に 日本 国 内 使用 。 話者 人口 つく 調査 国 内 ・ 国外 問う いま 日本 人口 基づく 考える 一般 的 。 日本 国 内 法 令 上 日本 語 公用 語 国 語 定める 直接 規定 。 法令 日本 語 記す 裁判 所 法 おく 裁判 所 日本 語 用いる 同法 条 文字 ・ 活字 文 化 振興 法 おく 国語 日本 語 同一 視 同法 条 条 他 多い 法 令 おく 日本 語 唯一 公用 語 国 語 前提 。 法 文 だけ 公用 文 すべて 日本 語 用いる 学校 教育 日本 語 国 語 教える 。 日本 テレビ ラジオ 映画 放送 小説 漫画 新聞 出版 分野 日本 語 使う 。 国外 ドラマ 映画 放送 場合 基本 的 日本 語 訳す 字幕 付ける 声 当てる 放送 受ける 手 日本 語 理解 前提 作成 。 原語 まま 放送 ・ 出版 存在 外国 向ける 発表 前 提 論 文 もしい は 日本 在住 外 国 人 あるいは 原語 学習 者 限る 人 対象 大 多数 日本 人 向ける 。 日本 国 外 主 中 南米 ペルー ・ ブラジル ・ ボリビア ・ ドミニカ 共和 国 ・ パラグアイ ハワイ 日本 人 移民 間 日本 語 使用 みる 世 ・ 世 世代 下るい したがう 非 日本 語 話 者 多い 。 太平 洋 戦争 終結 以前 日本 領 日本 勢力 下 朝鮮 総督 府 朝鮮 半島 ・ 台湾 総督 府 台 湾 ・ 旧 満州 国 現在 中華 人民 共和 国 一部 ・ 樺太 庁 樺太 サハリン ・ 旧 南洋 庁 南洋 諸島 現在 北マリアナ 諸島 ・ パラオ ・ マーシャル 諸島 ・ ミクロネシア 連邦 地域 日本 語 教育 受ける 人 中 現在 日本 語 記憶 話す 人 。 台湾 先住 民 異なる 部族 同士 会 話 日本 語 用いる だけ 宜蘭 クレオール 日本 語 タイヤル 語 クレオール 言 語 存在 。 パラオ アンガウル 州 歴史 的 経緯 日本 語 公用 語 一 採用 現在 州 内 日本 語 日常 会 話 用いる 住民 存在 象徴 的 留まる 。 日本 国 外 日本 語 学習 者 年 調査 万 人 のぼり 中華 人民 共和 国 約 万 人 インドネシア 約 万 人 大韓 民 国 約 万 人 オーストラリア 約 万 人 台湾 約 万 人 上位 。 地域 別 東 アジア ・ 東南 アジア 全体 学習 者 約 割 占める 。 日本 語 教育 行う 地域 か国 ・ 地域 及ぶ 。 日本 国 内 日本 語 学習 者 アジア 地域 約 万 人 中心 約 万 人 上る 。 系統 日本 語 範囲 本土 方言 場合 琉球 語 日本 語 同 系統 言 語 両 者 日 琉 語 族 形成 。 琉球 列 島 旧 琉球 王国 領域 言葉 日本 語 系統 同じく 別 言語 琉球 語 琉球 諸 語 日本 語 まとめる 日 琉 語 族 。 共通 点 多い 日本 語 一 方言 琉球 方言 場合 場合 日本 語 孤立 言語 位置 づけ 。 日本 語 族 系統 明らか 年 年 書物 いく 理論 仮 説 いまだ 総意 える 至る 記述 。 学問 的 系統 断言 言語 学 的 しばしば 孤立 言語 分類 多い 。 アルタイ 諸語 属 する 説 明治 時代 末 注目 。 根拠 古代 日本 語 大和 言葉 おく 語頭 音流 音 立つ 一種 母音 調和 みる 挙げる 。 古代 日本 語 上記 特徴 みる 日本 語 類 型 アルタイ 型 言語 根拠 。 日本 語 トルコ 系 言語 基礎 語彙 似る 部分 意味 日本 語 はい ウズベク 語 ハ 。 アルタイ 諸語 属 する 言語 親族 関係 支持 学 者 ほう まだ 多い 最近 イギリス アルタイ 諸語 親族 関係 否定 学 者 現れる 。 アイヌ 語 語 順 語 順 おく 日本 語 似る 。 文法 ・ 形態 類 型 論 的 異なる 抱合 語 属する 音韻 構造 有声 ・ 無声 区 別 ない 閉 音節 多い 相違 。 基礎 語 彙 類似 関する 指摘 例 不 充分 。 一般 似る 語 中 日本 語 アイヌ 語 借 用語 多い 含む みる 。 朝鮮 語 語 順 文法 構造 類似 点 非常 多い 。 音韻 面 固有 語 おく 語頭 流音 立 た 一種 母音 調和 みる 共通 類似 点 結果 日本 語 朝鮮 語 アルタイ 諸語 分類 場合 。 世界 諸 言語 広い 比較 場合 広い 朝鮮 語 日本 語 最も 近い 言語 。 閉音 節 子音 連結 存在 有声 ・ 無声 区 別 ない いう 相違 。 基礎 語彙 共通 点 かなり 相違 面 。 基礎 語 彙 関連 朝鮮 半島 死語 高句 麗 語 数詞 重要 基礎 語彙 似る 新村 出る 指摘 。 高句 麗 語 記録 非常 少 ない 合わせる 約 単語 記録 保存 。 高句 麗 語 鉛 なまり 那勿 ナムル 泉 いずみ 於乙 呼ぶ 記録 高句 麗 武将 泉 蓋 蘇 文 日本 書紀 伊梨 柯須 彌 イリカスミ 記録 泉 いずみ 高句 麗 語 於乙 イリ 呼ぶ 分かる 。 高句 麗 語 水 買 マイ 土 つし 内谷 旦 口くち 口 次 三 密 五 于 次七 難隱 十 德 高句 麗語 訓読み 現代 朝鮮 語 訓読み 日本 語 訓読み 非常 似る 分かる 。 中国 語 関係 関する 日本 語 中国 漢字 借用 語 広 範囲 取り入れる 語彙 漢字 用いる 関する 大きい だ 影響 受ける 。 語 順 文法 音韻 大きい 異なる 系統 論 的 別 系統 言語 。 南方 系 オーストロネシア 語 族 音韻 体 系 語彙 関する 類似 指摘 。 ドラヴィダ 語 族 関係 主張 説 認める 研究 者 少 ない 。 大野 晋 日本 語 語彙 ・ 文法 点 タミル 語 共通 点 持つ 説 唱える 比較 言語 学 方法 上 問題 批判 多い レプチャ 語 ・ ヘブライ 語 同系 論 過去 存在 関する 疑似 科 学 範 疇 ...
